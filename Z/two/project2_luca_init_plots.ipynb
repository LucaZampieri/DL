# %%
import torch
import math
from torch import Tensor
import matplotlib.pyplot as plt 

# imports from this same folder
import loadData
import baseline
import optim
import modules
import trainAndTest

# %%
torch.manual_seed(40)
print('Pytorch version: ',torch.__version__)
PLOT_FOLDER = 'plot_folder/'
# Out:
# Pytorch version:  0.3.1.post2

# %%
# Generate data with target 0 if outside the circle or 1 if inside
train_input, train_target = loadData.generate_disc_set(1000)
test_input, test_target = loadData.generate_disc_set(1000)

# see if data are close to be balanced and plot the dataset
loadData.plot_data(train_input, train_target, show_plot = False)

# check what accuracy we could expect with a simple baseline
# e.g. with a linear classifier after having added the L2 norm of the points
baseline.baseline_linear_model(train_input,train_target,test_input,test_target)

# convert targets to one-hot encoding
train_target = loadData.convert_to_one_hot(train_target)
test_target  = loadData.convert_to_one_hot(test_target)
print('Targets converted to one-hot')

# Normalize inplace the data
loadData.normalize_data(train_input)
loadData.normalize_data(test_input)
# Out:
# #samples:        torch.Size([1000, 2])
# Are the classes balanced?
# #true_samples:   torch.Size([504, 2])
# #false_samples:  torch.Size([496, 2])
# Baseline accuracy: 99.0 %
# Targets converted to one-hot

# %%
# create the model

#loss = LossBCE()




optimizers = [optim.SGDOptimizer, optim.SGDmomOptimizer, optim.AdamOptimizer, optim.BFGSOptimizer]
losses = [modules.LossMSE, modules.LossBCE]

# %%
lr = 0.005
loss_lists = []
train_accs = []
for i in range(20):
    Lin1 = modules.Linear(2,25)
    Lin2 = modules.Linear(25,25)
    Lin3 = modules.Linear(25,2)
    act1 = modules.ReLU()
    act2 = modules.ReLU()
    act3 = modules.Tanh()
    act4 = modules.Sigmoid()
    layers = [
        Lin1,
        act1,
        Lin2,
        act2,
        Lin3,
        act3]
    loss = modules.LossMSE()
    model = modules.Sequential(layers, loss)
    optimizer = optimizers[0](model, lr) # 
    epochs = 1000
    mini_batch_size = 50
    loss_list, train_acc = trainAndTest.train(model, optimizer, loss, train_input, train_target,\
                                              epochs, mini_batch_size, verbose = False)
    loss_lists.append(loss_list)
    train_accs.append(train_acc)

    print('optimizer: ',optimizer.name)
    print('learning rate: ',lr)
    print('minimum loss: ',min(loss_list))
    print('maximum accuracy: ',max(train_acc))
    print('On test: ', trainAndTest.test(model,test_input,test_target) )
    trainAndTest.plot_loss_accuracy(loss_list, train_acc)
# Out:
# 100%|██████████| 1000/1000 [00:03<00:00, 267.42it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  22.81358775496483
# maximum accuracy:  981
# On test:  959
# 100%|██████████| 1000/1000 [00:03<00:00, 270.92it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  21.60745546221733
# maximum accuracy:  988
# On test:  988
# 100%|██████████| 1000/1000 [00:03<00:00, 263.49it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  21.97108107805252
# maximum accuracy:  983
# On test:  948
# 100%|██████████| 1000/1000 [00:05<00:00, 199.48it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  22.73338434100151
# maximum accuracy:  985
# On test:  950
# 100%|██████████| 1000/1000 [00:04<00:00, 245.07it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  25.265987932682037
# maximum accuracy:  978
# On test:  932
# 100%|██████████| 1000/1000 [00:03<00:00, 267.12it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  23.389511704444885
# maximum accuracy:  982
# On test:  957
# 100%|██████████| 1000/1000 [00:03<00:00, 269.24it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  23.74400770664215
# maximum accuracy:  982
# On test:  982
# 100%|██████████| 1000/1000 [00:03<00:00, 270.35it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  22.83587172627449
# maximum accuracy:  985
# On test:  978
# 100%|██████████| 1000/1000 [00:03<00:00, 271.57it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  24.20091512799263
# maximum accuracy:  981
# On test:  949
# 100%|██████████| 1000/1000 [00:04<00:00, 248.20it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  21.541403710842133
# maximum accuracy:  985
# On test:  932
# 100%|██████████| 1000/1000 [00:03<00:00, 269.69it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  20.973553881049156
# maximum accuracy:  984
# On test:  973
# 100%|██████████| 1000/1000 [00:04<00:00, 247.25it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  22.41601264476776
# maximum accuracy:  983
# On test:  987
# 100%|██████████| 1000/1000 [00:03<00:00, 265.07it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  22.895523130893707
# maximum accuracy:  984
# On test:  961
# 100%|██████████| 1000/1000 [00:03<00:00, 269.57it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  24.129434168338776
# maximum accuracy:  981
# On test:  937
# 100%|██████████| 1000/1000 [00:03<00:00, 270.95it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  21.771715760231018
# maximum accuracy:  985
# On test:  942
# 100%|██████████| 1000/1000 [00:03<00:00, 273.34it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  22.394500732421875
# maximum accuracy:  983
# On test:  943
# 100%|██████████| 1000/1000 [00:03<00:00, 269.44it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  21.552027761936188
# maximum accuracy:  984
# On test:  947
# 100%|██████████| 1000/1000 [00:03<00:00, 268.71it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  23.542565122246742
# maximum accuracy:  983
# On test:  952
# 100%|██████████| 1000/1000 [00:03<00:00, 267.83it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  23.755035638809204
# maximum accuracy:  987
# On test:  939
# 100%|██████████| 1000/1000 [00:03<00:00, 266.17it/s]
# optimizer:  SGD
# learning rate:  0.005
# minimum loss:  24.40071591734886
# maximum accuracy:  980
# On test:  957

# %%
import pickle
def read(filename):
    with open (filename, 'rb') as fp:
        itemlist = pickle.load(fp)
    return itemlist
def write(filename,itemlist):
    with open(filename, 'wb') as fp:
        pickle.dump(itemlist, fp)

# %%
import numpy as np

# %%
losses_array = np.array(loss_lists)
acc_array = np.array(train_accs)

losses_mean=losses_array.mean(0)
losses_std=losses_array.std(0)

acc_mean = acc_array.mean(0)
acc_std = acc_array.std(0)

losses_std.shape
# Out:
# (1000,)

# %%
def plot_mean_and_var(mean, std, style, color,transparency,lenght_array=1000, labels=[None,None]):
    plt.plot(range(lenght_array),mean,style+color[0], label=labels[0])
    plt.fill_between(range(lenght_array), mean+(std*1), mean-std, facecolor =color[1], alpha=transparency,label=labels[1])
    return plt

# %%
plot_mean_and_var(losses_mean,losses_std,':',['r','m'],transparency=0.3, labels=['mean_','std_'])
plt.show()

# %% [raw]
# FOLDER_2 = 'pickles_for_init/'
# init_method = 'normal_0_00001'
# write(FOLDER_2+'losses_mean_'+init_method+'.p',losses_mean)
# write(FOLDER_2+'losses_std_'+init_method+'.p',losses_std)
# write(FOLDER_2+'acc_mean_'+init_method+'.p',acc_mean)
# write(FOLDER_2+'acc_std_'+init_method+'.p',acc_std)

# %%
init_method = 'standard'
losses_mean_std = read(FOLDER_2+'losses_mean_'+init_method+'.p')
losses_std_std = read(FOLDER_2+'losses_std_'+init_method+'.p')
acc_mean_std = read(FOLDER_2+'acc_mean_'+init_method+'.p')
acc_std_std = read(FOLDER_2+'losses_mean_'+init_method+'.p')

# xavier
init_method = 'xavier'
losses_mean_xavier = read(FOLDER_2+'losses_mean_'+init_method+'.p')
losses_std_xavier = read(FOLDER_2+'losses_std_'+init_method+'.p')
acc_mean_xavier = read(FOLDER_2+'acc_mean_'+init_method+'.p')
acc_std_xavier = read(FOLDER_2+'losses_mean_'+init_method+'.p')

# normal 0, 1
init_method = 'normal_0_1'
losses_mean_0_1 = read(FOLDER_2+'losses_mean_'+init_method+'.p')
losses_std_0_1 = read(FOLDER_2+'losses_std_'+init_method+'.p')
acc_mean_0_1 = read(FOLDER_2+'acc_mean_'+init_method+'.p')
acc_std_0_1 = read(FOLDER_2+'losses_mean_'+init_method+'.p')

# normal 0, 0.01
init_method = 'normal_0_001'
losses_mean_0_001 = read(FOLDER_2+'losses_mean_'+init_method+'.p')
losses_std_0_001 = read(FOLDER_2+'losses_std_'+init_method+'.p')
acc_mean_0_001 = read(FOLDER_2+'acc_mean_'+init_method+'.p')
acc_std_0_001 = read(FOLDER_2+'losses_mean_'+init_method+'.p')

# %%
fig = plt.figure(figsize=(10,5))
losses_to_plot = [(losses_mean_std,losses_std_std),(losses_mean_xavier,losses_std_xavier),\
                 (losses_mean_0_1,losses_std_0_1),(losses_mean_0_001,losses_std_0_001)]
accs_to_plot = [(acc_mean_std,acc_std_std),(acc_mean_xavier,acc_std_xavier),\
                 (acc_mean_0_1,acc_std_0_1),(acc_mean_0_001,acc_std_0_001)]

colors = ['r','b','g','c']
inits = ['std', 'xavier','normal_0,1','normal_0,0.01']
for i,(mean, std) in enumerate(losses_to_plot[:]):
    plot_mean_and_var(mean,std,'-',[colors[i],colors[i]],transparency=0.3, labels=['mean_'+inits[i],'std_'+inits[i]])
plt.legend()
plt.grid()
plt.legend()
plt.xlabel('Epochs')
plt.xlim(0,1000)
plt.xticks(range(0,1000,100))
plt.ylabel('Loss')
plt.title('Loss per initialization method')
plt.show()
fig.savefig(FOLDER_2+'losses_inits_bis')

# %%
fig2 = plt.figure(figsize=(10,5))
for i,(mean, std) in enumerate(accs_to_plot[:]):
    plot_mean_and_var(mean/10,std/10,'-',[colors[i],colors[i]],transparency=0.3, labels=['mean_'+inits[i],'std_'+inits[i]])
plt.legend()
plt.grid()
plt.legend()
plt.xlabel('Epochs')
plt.xlim(0,1000)
plt.xticks(range(0,1000,100))
plt.ylabel('Accuracy in %')
plt.title('Accuracy per initialization method')
plt.show()
fig2.savefig(FOLDER_2+'acc_inits_bis')

# %%
p0 = plt.figure(0)
loss_lists = [loss_list_sgd, loss_list_mom, loss_list_adam, loss_list_BFGS_3]
train_accs = [train_acc_sgd, train_acc_mom, train_acc_adam, train_acc_BFGS_3]
labels=['SGD','SGDmom','Adam','BFGS']
for i,loss_list in enumerate(loss_lists):
    plt.plot(loss_list, label=labels[i])
plt.grid()
plt.legend()
plt.xlabel('Epochs')
plt.xlim(0,1000)
plt.ylabel('Loss')
plt.title('Loss per optimizer')
plt.show()
p0.savefig(PLOT_FOLDER+'loss per optimizer9')

# %%
p1 = plt.figure(3)
labels=['SGD','SGDmom','Adam','BFGS']
for i,train_acc in enumerate(train_accs):
    plt.plot([x/train_input.size(0)*100 for x in train_acc], label=labels[i])
plt.grid()
plt.legend()
plt.xlabel('Epochs')
plt.xlim(0,1000)
plt.ylabel('Accuracy in %')
plt.title('Accuracy per optimizer')
plt.show()
p1.savefig(PLOT_FOLDER+'accuracy per optimizer9')

# %% [markdown]
# # Variations:
