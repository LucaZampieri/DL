# %%
import dlc_bci as bci
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
from torch import nn, optim
from torch.nn import functional as F

import random
import time

# fix seeds
torch.manual_seed(1)
random.seed(1)
np.random.seed(1)

# from this same folder
import baseline
from nets import MyNet
from nets import MyNet2
from nets import MyNet3
import helpers
from helpers import BCELoss
from helpers import N_true

print('Version of PyTorch:', torch.__version__,', and we used: 0.4.0')

# %load_ext autoreload

# %autoreload 2
# Out:
# Version of PyTorch: 0.4.0 , and we used: 0.4.0
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Import data

# %%
big_data = True 
train_input, train_target = bci.load(root ="./data_bci",download=False, one_khz=big_data)

test_input, test_target = bci.load(root ="./data_bci", train = False, download=False, one_khz=False)

print(str(type(train_input)), train_input.shape)
print(str(type(train_target)), train_target.size())
print(str(type(test_input)), test_input.size())
print(str(type(test_target)), test_target.size())

# Vizualize the data
#helpers.visualize_data(train_input, train_target, test_input,test_target)

# normalize the data
train_input = (train_input - torch.mean(train_input,0,keepdim=True))/torch.std(train_input,0,True)
test_input = (test_input - torch.mean(test_input,0,keepdim=True))/torch.std(test_input,0,True)

# Make non-neural-network baselines
train_input_baselines = train_input.clone()
train_target_baselines = train_target.clone()
#baseline.lousy_baselines(train_input_baselines, train_target_baselines,test_input, test_target)
# Out:
# <class 'torch.Tensor'> torch.Size([316, 28, 500])
# <class 'torch.Tensor'> torch.Size([316])
# <class 'torch.Tensor'> torch.Size([100, 28, 50])
# <class 'torch.Tensor'> torch.Size([100])

# %% [markdown]
# ## Train

# %%
t0=time.clock() # save the current time
# set parameters and initialises modules
net = MyNet3()
#optimizer = optim.Adam(net.parameters(), lr=0.00005)
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.4)

batch_size = 15
n_max_epochs = 250
n_val_samples = 50

# transform the dataset such that they can be fed to the network
train_X, train_Y, val_X, val_Y = helpers.prepare_train_with_validation(train_input,\
                                                                       train_target,\
                                                                       n_val_samples,\
                                                                       DA=True)
test_X, test_Y = helpers.prepare_test(test_input,test_target)

train_losses = []
val_losses = []
val_acc = []
train_acc = []
VERBOSE = True

for epoch in range(n_max_epochs):  # loop over the dataset multiple times
    
    net.train() # sets the net in training mode --> dropout activated
    train_loss = 0.0
    num_correct_per_epoch = 0.0
    # train_X, train_Y = helpers.shuffle_data(input_=train_X, target_=train_Y) # shuffles the training between epochs
    for b in range(0, train_X.shape[0], batch_size):   #Train batch by batch
        
        # take care of the last batch (which size could not match with the remaining)
        end = batch_size
        if((b+end)>len(train_X)): end=b+end-len(train_X) 
        
        # make predictions and make an optimization step
        output = net(train_X[b:b+end])
        loss = BCELoss(train_Y[b:b+end],output.squeeze())
        loss.backward()
        optimizer.step()
        net.zero_grad()
        
        # update loss and num of correct prediction per batch
        train_loss += loss.data
        num_correct_per_batch = N_true(output, train_Y[b:b+end])
        num_correct_per_epoch += num_correct_per_batch
    
    # evaluate validation 
    net.eval() # set the net in eval mode --> dropout deactivated
    val_pred = net(val_X)
    test_pred = net(Variable(torch.unsqueeze(test_input,1)))
    
    # append values to lists to keep track of the evolution of loss and accuracy
    train_losses.append(train_loss) #add train loss
    train_acc.append(num_correct_per_epoch/train_X.shape[0]) 
    val_losses.append(BCELoss(val_Y,val_pred).data) #add validation loss
    val_acc.append(N_true(val_pred,val_Y)/val_X.shape[0]) #add validation accuracy
    if VERBOSE == True:
        print("\nEpoch ", epoch)
        print("classification accuracy on training set: {}".format(train_acc[epoch].data.numpy()))
        print("classification accuracy on validation set: {}".format(val_acc[epoch].data.numpy()))
        print("classification accuracy on test set: {}%".format((N_true(net(Variable(torch.unsqueeze(test_input,1))),Variable(test_target)))*100/test_input.shape[0]))


        
t1=time.clock() # save the current time
print("time for training : ", t1-t0, ' seconds')
plt.plot(range(epoch+1),val_losses,range(epoch+1),train_losses)
plt.legend(['validation error', 'training error'])
plt.show()

test_pred = net(Variable(torch.unsqueeze(test_input,1)))
print("classification accuracy on test set: {}%".format((N_true(net(Variable(torch.unsqueeze(test_input,1))),Variable(test_target)))*100/test_input.shape[0]))
# Out:
# Validation shapes
#  torch.Size([500, 1, 28, 50]) torch.Size([500])
# Train shapes
#  torch.Size([2660, 1, 28, 50]) torch.Size([2660])
# Test shapes
#  torch.Size([100, 1, 28, 50]) torch.Size([100])
#
# Epoch  0
# classification accuracy on training set: 0.49624061584472656
# classification accuracy on validation set: 0.5
# classification accuracy on test set: 50.0%
#
# Epoch  1
# classification accuracy on training set: 0.49849623441696167
# classification accuracy on validation set: 0.5
# classification accuracy on test set: 50.0%
#
# Epoch  2
# classification accuracy on training set: 0.5161654353141785
# classification accuracy on validation set: 0.46799999475479126
# classification accuracy on test set: 49.0%
#
# Epoch  3
# classification accuracy on training set: 0.5541353225708008
# classification accuracy on validation set: 0.4339999854564667
# classification accuracy on test set: 47.0%
#
# Epoch  4
# classification accuracy on training set: 0.6011278033256531
# classification accuracy on validation set: 0.42399999499320984
# classification accuracy on test set: 45.0%
#
# Epoch  5
# classification accuracy on training set: 0.6304511427879333
# classification accuracy on validation set: 0.44600000977516174
# classification accuracy on test set: 42.0%
#
# Epoch  6
# classification accuracy on training set: 0.6530075073242188
# classification accuracy on validation set: 0.47600001096725464
# classification accuracy on test set: 44.0%
#
# Epoch  7
# classification accuracy on training set: 0.6657894849777222
# classification accuracy on validation set: 0.4959999918937683
# classification accuracy on test set: 47.0%
#
# Epoch  8
# classification accuracy on training set: 0.682330846786499
# classification accuracy on validation set: 0.48399999737739563
# classification accuracy on test set: 53.0%
#
# Epoch  9
# classification accuracy on training set: 0.6936089992523193
# classification accuracy on validation set: 0.5260000228881836
# classification accuracy on test set: 54.0%
#
# Epoch  10
# classification accuracy on training set: 0.7078947424888611
# classification accuracy on validation set: 0.5619999766349792
# classification accuracy on test set: 55.0%
#
# Epoch  11
# classification accuracy on training set: 0.7169172763824463
# classification accuracy on validation set: 0.5540000200271606
# classification accuracy on test set: 56.0%
#
# Epoch  12
# classification accuracy on training set: 0.7342105507850647
# classification accuracy on validation set: 0.5680000185966492
# classification accuracy on test set: 62.0%
#
# Epoch  13
# classification accuracy on training set: 0.746616542339325
# classification accuracy on validation set: 0.5699999928474426
# classification accuracy on test set: 62.0%
#
# Epoch  14
# classification accuracy on training set: 0.7654135227203369
# classification accuracy on validation set: 0.5699999928474426
# classification accuracy on test set: 63.0%
#
# Epoch  15
# classification accuracy on training set: 0.784586489200592
# classification accuracy on validation set: 0.593999981880188
# classification accuracy on test set: 64.0%
#
# Epoch  16
# classification accuracy on training set: 0.8082706928253174
# classification accuracy on validation set: 0.6299999952316284
# classification accuracy on test set: 65.0%
#
# Epoch  17
# classification accuracy on training set: 0.8274435997009277
# classification accuracy on validation set: 0.6259999871253967
# classification accuracy on test set: 66.0%
#
# Epoch  18
# classification accuracy on training set: 0.8484962582588196
# classification accuracy on validation set: 0.6320000290870667
# classification accuracy on test set: 66.0%
#
# Epoch  19
# classification accuracy on training set: 0.8691729307174683
# classification accuracy on validation set: 0.6420000195503235
# classification accuracy on test set: 67.0%
#
# Epoch  20
# classification accuracy on training set: 0.8928571343421936
# classification accuracy on validation set: 0.6439999938011169
# classification accuracy on test set: 68.0%
#
# Epoch  21
# classification accuracy on training set: 0.9071428775787354
# classification accuracy on validation set: 0.6460000276565552
# classification accuracy on test set: 68.0%
#
# Epoch  22
# classification accuracy on training set: 0.9251879453659058
# classification accuracy on validation set: 0.6539999842643738
# classification accuracy on test set: 70.0%
#
# Epoch  23
# classification accuracy on training set: 0.9349623918533325
# classification accuracy on validation set: 0.6639999747276306
# classification accuracy on test set: 68.0%
#
# Epoch  24
# classification accuracy on training set: 0.9496240615844727
# classification accuracy on validation set: 0.6919999718666077
# classification accuracy on test set: 69.0%
#
# Epoch  25
# classification accuracy on training set: 0.9612782001495361
# classification accuracy on validation set: 0.699999988079071
# classification accuracy on test set: 70.0%
#
# Epoch  26
# classification accuracy on training set: 0.9672932624816895
# classification accuracy on validation set: 0.7139999866485596
# classification accuracy on test set: 71.0%
#
# Epoch  27
# classification accuracy on training set: 0.9729323387145996
# classification accuracy on validation set: 0.7300000190734863
# classification accuracy on test set: 71.0%
#
# Epoch  28
# classification accuracy on training set: 0.9781954884529114
# classification accuracy on validation set: 0.7279999852180481
# classification accuracy on test set: 70.0%
#
# Epoch  29
# classification accuracy on training set: 0.9815789461135864
# classification accuracy on validation set: 0.7379999756813049
# classification accuracy on test set: 70.0%
#
# Epoch  30
# classification accuracy on training set: 0.9868420958518982
# classification accuracy on validation set: 0.7319999933242798
# classification accuracy on test set: 72.0%
#
# Epoch  31
# classification accuracy on training set: 0.9894737005233765
# classification accuracy on validation set: 0.7360000014305115
# classification accuracy on test set: 73.0%
#
# Epoch  32
# classification accuracy on training set: 0.9932330846786499
# classification accuracy on validation set: 0.7319999933242798
# classification accuracy on test set: 72.0%
#
# Epoch  33
# classification accuracy on training set: 0.995488703250885
# classification accuracy on validation set: 0.734000027179718
# classification accuracy on test set: 72.0%
#
# Epoch  34
# classification accuracy on training set: 0.9973683953285217
# classification accuracy on validation set: 0.7319999933242798
# classification accuracy on test set: 72.0%
#
# Epoch  35
# classification accuracy on training set: 0.9981203079223633
# classification accuracy on validation set: 0.7279999852180481
# classification accuracy on test set: 72.0%
#
# Epoch  36
# classification accuracy on training set: 0.9988721609115601
# classification accuracy on validation set: 0.7300000190734863
# classification accuracy on test set: 73.0%
#
# Epoch  37
# classification accuracy on training set: 0.9992481470108032
# classification accuracy on validation set: 0.734000027179718
# classification accuracy on test set: 73.0%
#
# Epoch  38
# classification accuracy on training set: 0.9996240735054016
# classification accuracy on validation set: 0.734000027179718
# classification accuracy on test set: 74.0%
#
# Epoch  39
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7319999933242798
# classification accuracy on test set: 74.0%
#
# Epoch  40
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7279999852180481
# classification accuracy on test set: 76.0%
#
# Epoch  41
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7239999771118164
# classification accuracy on test set: 76.0%
#
# Epoch  42
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7239999771118164
# classification accuracy on test set: 76.0%
#
# Epoch  43
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7260000109672546
# classification accuracy on test set: 77.0%
#
# Epoch  44
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7200000286102295
# classification accuracy on test set: 76.0%
#
# Epoch  45
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.722000002861023
# classification accuracy on test set: 76.0%
#
# Epoch  46
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7200000286102295
# classification accuracy on test set: 76.0%
# Epoch  47
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.722000002861023
# classification accuracy on test set: 76.0%
#
# Epoch  48
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7200000286102295
# classification accuracy on test set: 76.0%
#
# Epoch  49
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.722000002861023
# classification accuracy on test set: 76.0%
#
# Epoch  50
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.722000002861023
# classification accuracy on test set: 76.0%
#
# Epoch  51
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.722000002861023
# classification accuracy on test set: 76.0%
#
# Epoch  52
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7260000109672546
# classification accuracy on test set: 76.0%
#
# Epoch  53
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7260000109672546
# classification accuracy on test set: 76.0%
#
# Epoch  54
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7279999852180481
# classification accuracy on test set: 76.0%
#
# Epoch  55
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7279999852180481
# classification accuracy on test set: 76.0%
#
# Epoch  56
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7279999852180481
# classification accuracy on test set: 76.0%
#
# Epoch  57
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7300000190734863
# classification accuracy on test set: 77.0%
#
# Epoch  58
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7319999933242798
# classification accuracy on test set: 77.0%
#
# Epoch  59
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.734000027179718
# classification accuracy on test set: 77.0%
#
# Epoch  60
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.734000027179718
# classification accuracy on test set: 77.0%
#
# Epoch  61
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.734000027179718
# classification accuracy on test set: 77.0%
#
# Epoch  62
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7360000014305115
# classification accuracy on test set: 77.0%
#
# Epoch  63
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7400000095367432
# classification accuracy on test set: 77.0%
#
# Epoch  64
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7400000095367432
# classification accuracy on test set: 76.0%
#
# Epoch  65
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7400000095367432
# classification accuracy on test set: 76.0%
#
# Epoch  66
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7400000095367432
# classification accuracy on test set: 76.0%
#
# Epoch  67
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7419999837875366
# classification accuracy on test set: 76.0%
#
# Epoch  68
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7440000176429749
# classification accuracy on test set: 76.0%
#
# Epoch  69
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  70
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  71
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  72
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  73
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  74
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  75
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  76
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7459999918937683
# classification accuracy on test set: 76.0%
#
# Epoch  77
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7480000257492065
# classification accuracy on test set: 76.0%
#
# Epoch  78
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.75
# classification accuracy on test set: 75.0%
#
# Epoch  79
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.75
# classification accuracy on test set: 75.0%
#
# Epoch  80
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7519999742507935
# classification accuracy on test set: 75.0%
#
# Epoch  81
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7519999742507935
# classification accuracy on test set: 75.0%
#
# Epoch  82
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7519999742507935
# classification accuracy on test set: 75.0%
#
# Epoch  83
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7519999742507935
# classification accuracy on test set: 75.0%
#
# Epoch  84
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7519999742507935
# classification accuracy on test set: 75.0%
#
# Epoch  85
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7519999742507935
# classification accuracy on test set: 75.0%
#
# Epoch  86
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7540000081062317
# classification accuracy on test set: 75.0%
#
# Epoch  87
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7540000081062317
# classification accuracy on test set: 75.0%
#
# Epoch  88
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7540000081062317
# classification accuracy on test set: 74.0%
#
# Epoch  89
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7540000081062317
# classification accuracy on test set: 74.0%
#
# Epoch  90
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7540000081062317
# classification accuracy on test set: 74.0%
#
# Epoch  91
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 74.0%
#
# Epoch  92
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 74.0%
#
# Epoch  93
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 74.0%
#
# Epoch  94
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 74.0%
#
# Epoch  95
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 74.0%
#
# Epoch  96
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 74.0%
#
# Epoch  97
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  98
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
# Epoch  99
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  100
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  101
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  102
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  103
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  104
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  105
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  106
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  107
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  108
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  109
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  110
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  111
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  112
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  113
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 74.0%
#
# Epoch  114
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 74.0%
#
# Epoch  115
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 74.0%
#
# Epoch  116
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 74.0%
#
# Epoch  117
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  118
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  119
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  120
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  121
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  122
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  123
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  124
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  125
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  126
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  127
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  128
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  129
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  130
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  131
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  132
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  133
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  134
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  135
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  136
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  137
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  138
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7639999985694885
# classification accuracy on test set: 73.0%
#
# Epoch  139
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7639999985694885
# classification accuracy on test set: 73.0%
#
# Epoch  140
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  141
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  142
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  143
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  144
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  145
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 73.0%
#
# Epoch  146
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  147
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  148
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  149
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
# Epoch  150
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  151
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  152
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  153
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  154
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  155
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  156
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  157
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  158
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  159
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  160
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  161
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  162
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  163
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  164
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  165
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  166
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  167
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  168
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  169
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  170
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  171
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  172
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  173
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7620000243186951
# classification accuracy on test set: 72.0%
#
# Epoch  174
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  175
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  176
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  177
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  178
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  179
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  180
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  181
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7599999904632568
# classification accuracy on test set: 72.0%
#
# Epoch  182
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  183
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  184
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  185
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  186
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  187
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  188
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  189
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  190
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  191
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  192
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  193
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  194
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  195
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  196
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  197
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  198
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  199
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  200
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
# Epoch  201
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  202
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  203
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  204
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  205
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  206
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  207
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  208
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  209
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  210
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  211
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  212
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  213
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
#
# Epoch  214
# classification accuracy on training set: 1.0
# classification accuracy on validation set: 0.7580000162124634
# classification accuracy on test set: 72.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-8169fa9f4f04> in <module>()
#      35         output = net(train_X[b:b+end])
#      36         loss = BCELoss(train_Y[b:b+end],output.squeeze())
# ---> 37         loss.backward()
#      38         optimizer.step()
#      39         net.zero_grad()
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
test_pred = net(Variable(torch.unsqueeze(test_input,1)))
test_acc = (N_true(net(Variable(torch.unsqueeze(test_input,1))),Variable(test_target)))*100/test_input.shape[0]
print("classification accuracy on test set: {}%".format(test_acc))

plt.plot(np.asarray(train_acc)*100,'b', label='train')
plt.plot(np.asarray(val_acc)*100,'r',label='validation')
plt.plot(range(len(train_acc)),torch.ones(len(train_acc)).numpy()*test_acc.numpy())
plt.title('accuracy')
plt.grid(), plt.legend()
plt.show()
