# %%
import dlc_bci as bci
import numpy as np
np.random.seed(5687)
import matplotlib.pyplot as plt
import torch
torch.manual_seed(432)
import random
random.seed(452)
import time
from torch.autograd import Variable
from torch import nn, optim
from torch.nn import functional as F

# %% [markdown]
# ## Import data

# %%
big_data = True 
train_input, train_target = bci.load(root ="./data_bci", one_khz=big_data)
print(str(type(train_input)), train_input.size())
print(str(type(train_target)), train_target.size())
test_input, test_target = bci.load(root ="./data_bci", train = False, one_khz=False)
print(str(type(test_input)), test_input.size())
print(str(type(test_target)), test_target.size())
# Out:
# <class 'torch.Tensor'> torch.Size([316, 28, 500])
# <class 'torch.Tensor'> torch.Size([316])
# <class 'torch.Tensor'> torch.Size([100, 28, 50])
# <class 'torch.Tensor'> torch.Size([100])

# %% [markdown]
# ## visualize data

# %%
n_train_samples = train_target.size()[0]
print('Number of training samples = {}'.format(n_train_samples))
n_test_samples = test_target.size()[0]
print('Number of testing samples = {}'.format(n_test_samples))
n_channels = train_input.size()[1]
print('Number of channels = {}'.format(n_channels))
n_readings = train_input.size()[2]
print('Number of readings per channel = {}'.format(n_readings))

freq = 2*n_readings

tt = np.arange(0,0.5,1/freq)

for i in range(n_channels):
    plt.plot(tt,train_input[0,i,:].numpy())
    
plt.show()
# Out:
# Number of training samples = 316
# Number of testing samples = 100
# Number of channels = 28
# Number of readings per channel = 500

# %%
plt.plot(tt,train_input[10:27,8,:].numpy().transpose())
plt.show()

# %% [markdown]
# ## Augment Data using different sampling shift

# %%
def augment_data(train_X, train_Y): 
    
    big_data_set = torch.Tensor(0,28,50)
    big_target = torch.Tensor(0)
    for i in range(10):
        shifted_data = train_X[:,:,i::10]
        big_data_set = torch.cat((big_data_set,shifted_data),0)
        big_target = torch.cat((big_target,train_Y.type(torch.FloatTensor)),0)
    
    return big_data_set, big_target.type(torch.LongTensor)

# %% [markdown]
# ## Normalize augmented data

# %%
train_input = (train_input - torch.mean(train_input,0,keepdim=True))/torch.std(train_input,0,True)
test_input = (test_input - torch.mean(test_input,0,keepdim=True))/torch.std(test_input,0,True)

# %% [markdown]
# ## Define Network

# %%
class MyNet(nn.Module):
    def __init__(self):
        super(MyNet, self).__init__()
        
        # Layer 1
        self.conv1a = nn.Conv2d(1, 8, (1, 5), dilation=2) # Apply convolution on each channels
        self.batchnorm1a = nn.BatchNorm2d(8, False) # Normalize
        # Layer 2
        self.conv1b = nn.Conv2d(8, 16, (1, 5)) # Apply convolution on each channels
        self.batchnorm1b = nn.BatchNorm2d(16, False) # Normalize
        # Layer 3
        self.conv2 = nn.Conv2d(16,32,(28, 1)) # Apply one convolution on each timestamp
        self.batchnorm2 = nn.BatchNorm2d(32, False) # Normalize
        
        # Fully Connected Layers
        self.fc1 = nn.Linear(1216,256)
        self.fc2 = nn.Linear(256,128)
        self.fc3 = nn.Linear(128,64)
        self.fc4 = nn.Linear(64,1)
    
    def forward(self, x):

        #print("input shape : {}".format(x.shape))
        x = self.conv1a(x)
        #print("Shape after self.conv1a(x) : {}".format(x.shape))
        x = self.batchnorm1a(x)
        #print("Shape after self.batchnorm1a(x) : {}".format(x.shape))
        x = self.conv1b(x)
        #print("Shape after self.conv1b(x) : {}".format(x.shape))
        x = self.batchnorm1b(x)
        #print("Shape after self.batchnorm1b(x) : {}".format(x.shape))
        x = self.conv2(x)
        x = F.elu(self.batchnorm2(x))
        #print("Shape after secondConvolution : {}".format(x.shape))
        x = F.dropout2d(x,0.5)
        s = x.shape
        a = s[1]*s[2]*s[3] #s[1]*s[2]*s[3] = 32*1*42
        x = x.view(-1,a) 
        #print("Flatten shape for FC : {}".format(x.shape))
        x = F.elu(self.fc1(x))
        x = F.elu(self.fc2(x))
        x = F.dropout(x,0.5)
        x = F.elu(self.fc3(x))
        x = F.sigmoid(self.fc4(x))
        #print("Output format : {}".format(x.shape))
        
        return x

# %%
class MyNet2(nn.Module):
    def __init__(self):
        super(MyNet2, self).__init__()
        
        self.fc1 = nn.Linear(28*50,128)
        self.fc2 = nn.Linear(128,1)
        
    def forward(self,x):
        
        #print("input shape : {}".format(x.shape))
        x = x.view(-1,28*50)
        #print("Flatten shape for FC : {}".format(x.shape))
        x = F.dropout(x,0.5)
        x = F.relu(self.fc1(x))
        #print(self.fc2(x))
        x = F.sigmoid(self.fc2(x))
        
        return x

# %%
class MyNet3(nn.Module):
    def __init__(self):
        super(MyNet3, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 4, (1, 5), dilation=2)
        self.batchnorm1 = nn.BatchNorm2d(4,False)
        self.conv2 = nn.Conv2d(4,4,(28,1))
        self.batchnorm2 = nn.BatchNorm2d(4, False) # Normalize
        self.fc1 = nn.Linear(4*42,64)    
        self.fc2 = nn.Linear(64,1)
        
    def forward(self,x):
        
        #print("input shape : {}".format(x.shape))
        x = self.conv1(x)
        #print("Shape after self.conv1(x) : {}".format(x.shape))
        x = self.batchnorm1(x)
        #print("Shape after self.batchnorm1(x) : {}".format(x.shape))
        x = self.conv2(x)
        #print("Shape after self.conv2(x) : {}".format(x.shape))
        x = self.batchnorm2(x)
        #print("Shape after self.batchnorm2(x) : {}".format(x.shape))
        x = x.view(-1,4*42)
        #print("Flatten shape for FC : {}".format(x.shape))
        x = F.relu(self.fc1(x))
        x = F.dropout(x,0.6)
        #print("after fc1 : {}".format(x.shape))      
        x = F.sigmoid(self.fc2(x))
        
        return x

# %% [markdown]
# ## Train

# %%
def Validation(Y_pred, Y_true):
    return BCE(Y_true,Y_pred)

def N_true(Y_pred, Y_true):
    return torch.sum(torch.round(Y_pred).squeeze()==Y_true.float()).type(torch.FloatTensor)/Y_true.shape[0]
     
def BCE(Y_true,Y_pred):
    
    l = Variable(torch.Tensor(len(Y_true)))
    for i in range(len(Y_true)):
        if(Y_true[i]==1).data.numpy():
            l[i] = - Y_pred[i].log()
        else:
            l[i] = - (1-Y_pred[i]).log() 
        
    return torch.mean(l)

# %%
t0 = time.clock()
net = MyNet()
#optimizer = optim.Adam(net.parameters(), lr=0.00005)
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.4)

batch_size = 15
n_max_epochs = 200
n_validation_samples = 16

train_err = []
val_err = []
val_truth = []
train_truth = []

#Prepare validation data
val_idx = random.sample(range(n_train_samples), int(n_validation_samples)) # pick 16 high resolution samples
val_x, val_y = augment_data(train_input[torch.LongTensor(val_idx)],(train_target[torch.LongTensor(val_idx)]))
val_X = Variable(torch.unsqueeze(val_x,1),requires_grad=True)
val_Y = Variable(val_y)

#Prepare training data
train_idx = np.delete(np.arange(len(train_input)),val_idx)
train_x, train_y = augment_data(train_input[torch.LongTensor(train_idx)], train_target[torch.LongTensor(train_idx)])
train_X = Variable(torch.unsqueeze(train_x,1))
train_Y = Variable(train_y)
print("Train shapes \n", train_X.shape, train_Y.shape)

test_x, test_y = test_input, test_target#augment_data(test_input, test_target)
test_X = Variable(torch.unsqueeze(test_x,1))
test_Y = Variable(test_y)
print("Test shapes \n" ,test_X.shape, test_Y.shape)

for epoch in range(n_max_epochs):  # loop over the dataset multiple times
    print("\nEpoch ", epoch)
    
    net.train()
    
    train_loss = 0.0
    epoch_true = 0.0
    #print(len(train_X))
    
    for b in range(0, len(train_X), batch_size):   #Train batch by batch
    
        output = net(train_X.narrow(0, b, batch_size))
        loss = BCE(train_Y.narrow(0, b, batch_size),output.squeeze())
        #print(loss)
        net.zero_grad()
        loss.backward()
        optimizer.step()
        #scheduler.step(loss)
        train_loss = (train_loss + loss.data)/2
        batch_true = N_true(output, train_Y.narrow(0, b, batch_size))
        epoch_true = (epoch_true + batch_true)
        
    net.eval()  
    
    
    val_pred = net(val_X)
    train_err.append(train_loss) #add train loss
    val_err.append(Validation(val_pred,val_Y).data) #add validation loss
    val_truth.append(N_true(val_pred,val_Y)) #add validation accuracy
    print("classification accuracy on validation set: {}".format(val_truth[epoch].data.numpy()))
    train_truth.append(epoch_true/(len(train_input)/batch_size)) #add train accuracy
    print("classification accuracy on training set: {}".format(train_truth[epoch].data.numpy()))
    
    test_pred = net(Variable(torch.unsqueeze(test_input,1)))
#print("Binary Cross Entropy loss for test set: {}".format(BCE(Variable(test_target),test_pred)))
    print("classification accuracy on test set: {}%".format((N_true(net(Variable(torch.unsqueeze(test_input,1))),Variable(test_target)))*100))

    if(abs(train_loss-val_err[epoch])>0.3): 
        '''
        Early Stopping condition if error difference between train and validation too big.
        Train error reduces & Validation error increases -> overfitting'''
        #break
t1=time.clock()   
plt.plot(range(epoch+1),val_err,range(epoch+1),train_err)
plt.legend(['validation error', 'training error'])
plt.show()

print("time for training : ", t1-t0)
# Out:
# Train shapes
#  torch.Size([3000, 1, 28, 50]) torch.Size([3000])
# Test shapes
#  torch.Size([100, 1, 28, 50]) torch.Size([100])
#
# Epoch  0
# classification accuracy on validation set: 0.543749988079071
# classification accuracy on training set: 4.889237880706787
# classification accuracy on test set: 48.0%
#
# Epoch  1
# classification accuracy on validation set: 0.48750001192092896
# classification accuracy on training set: 5.136074542999268
# classification accuracy on test set: 45.0%
#
# Epoch  2
# classification accuracy on validation set: 0.5375000238418579
# classification accuracy on training set: 5.332276821136475
# classification accuracy on test set: 42.0%
#
# Epoch  3
# classification accuracy on validation set: 0.5625
# classification accuracy on training set: 5.537971496582031
# classification accuracy on test set: 42.0%
#
# Epoch  4
# classification accuracy on validation set: 0.5562499761581421
# classification accuracy on training set: 5.721518039703369
# classification accuracy on test set: 44.0%
#
# Epoch  5
# classification accuracy on validation set: 0.574999988079071
# classification accuracy on training set: 5.879745006561279
# classification accuracy on test set: 46.0%
#
# Epoch  6
# classification accuracy on validation set: 0.5687500238418579
# classification accuracy on training set: 6.003161907196045
# classification accuracy on test set: 43.0%
#
# Epoch  7
# classification accuracy on validation set: 0.5874999761581421
# classification accuracy on training set: 6.104428291320801
# classification accuracy on test set: 46.0%
#
# Epoch  8
# classification accuracy on validation set: 0.5874999761581421
# classification accuracy on training set: 6.218352794647217
# classification accuracy on test set: 46.0%
#
# Epoch  9
# classification accuracy on validation set: 0.5874999761581421
# classification accuracy on training set: 6.29746675491333
# classification accuracy on test set: 45.0%
#
# Epoch  10
# classification accuracy on validation set: 0.6000000238418579
# classification accuracy on training set: 6.39556884765625
# classification accuracy on test set: 48.0%
#
# Epoch  11
# classification accuracy on validation set: 0.637499988079071
# classification accuracy on training set: 6.522153377532959
# classification accuracy on test set: 48.0%
#
# Epoch  12
# classification accuracy on validation set: 0.65625
# classification accuracy on training set: 6.6962056159973145
# classification accuracy on test set: 47.0%
#
# Epoch  13
# classification accuracy on validation set: 0.675000011920929
# classification accuracy on training set: 6.968359470367432
# classification accuracy on test set: 51.0%
#
# Epoch  14
# classification accuracy on validation set: 0.699999988079071
# classification accuracy on training set: 7.174055099487305
# classification accuracy on test set: 58.999996185302734%
#
# Epoch  15
# classification accuracy on validation set: 0.7124999761581421
# classification accuracy on training set: 7.306967735290527
# classification accuracy on test set: 63.0%
#
# Epoch  16
# classification accuracy on validation set: 0.731249988079071
# classification accuracy on training set: 7.303802490234375
# classification accuracy on test set: 66.0%
#
# Epoch  17
# classification accuracy on validation set: 0.706250011920929
# classification accuracy on training set: 7.446206569671631
# classification accuracy on test set: 71.0%
#
# Epoch  18
# classification accuracy on validation set: 0.7562500238418579
# classification accuracy on training set: 7.67722225189209
# classification accuracy on test set: 72.0%
#
# Epoch  19
# classification accuracy on validation set: 0.7749999761581421
# classification accuracy on training set: 7.939879417419434
# classification accuracy on test set: 72.0%
#
# Epoch  20
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 8.174057006835938
# classification accuracy on test set: 74.0%
#
# Epoch  21
# classification accuracy on validation set: 0.800000011920929
# classification accuracy on training set: 8.341779708862305
# classification accuracy on test set: 75.0%
#
# Epoch  22
# classification accuracy on validation set: 0.800000011920929
# classification accuracy on training set: 8.579120635986328
# classification accuracy on test set: 82.0%
#
# Epoch  23
# classification accuracy on validation set: 0.800000011920929
# classification accuracy on training set: 8.841776847839355
# classification accuracy on test set: 86.0%
#
# Epoch  24
# classification accuracy on validation set: 0.768750011920929
# classification accuracy on training set: 8.990509033203125
# classification accuracy on test set: 86.0%
#
# Epoch  25
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 9.120255470275879
# classification accuracy on test set: 87.0%
#
# Epoch  26
# classification accuracy on validation set: 0.737500011920929
# classification accuracy on training set: 9.250001907348633
# classification accuracy on test set: 86.0%
#
# Epoch  27
# classification accuracy on validation set: 0.71875
# classification accuracy on training set: 9.325950622558594
# classification accuracy on test set: 85.0%
#
# Epoch  28
# classification accuracy on validation set: 0.7124999761581421
# classification accuracy on training set: 9.363924980163574
# classification accuracy on test set: 85.0%
#
# Epoch  29
# classification accuracy on validation set: 0.706250011920929
# classification accuracy on training set: 9.408228874206543
# classification accuracy on test set: 85.0%
#
# Epoch  30
# classification accuracy on validation set: 0.71875
# classification accuracy on training set: 9.436708450317383
# classification accuracy on test set: 84.0%
#
# Epoch  31
# classification accuracy on validation set: 0.7124999761581421
# classification accuracy on training set: 9.458860397338867
# classification accuracy on test set: 85.0%
#
# Epoch  32
# classification accuracy on validation set: 0.7124999761581421
# classification accuracy on training set: 9.471518516540527
# classification accuracy on test set: 85.0%
#
# Epoch  33
# classification accuracy on validation set: 0.7250000238418579
# classification accuracy on training set: 9.481012344360352
# classification accuracy on test set: 85.0%
#
# Epoch  34
# classification accuracy on validation set: 0.75
# classification accuracy on training set: 9.490506172180176
# classification accuracy on test set: 86.0%
#
# Epoch  35
# classification accuracy on validation set: 0.7562500238418579
# classification accuracy on training set: 9.490506172180176
# classification accuracy on test set: 86.0%
#
# Epoch  36
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 9.490506172180176
# classification accuracy on test set: 87.0%
#
# Epoch  37
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  38
# classification accuracy on validation set: 0.7562500238418579
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  39
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  40
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  41
# classification accuracy on validation set: 0.768750011920929
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  42
# classification accuracy on validation set: 0.7749999761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  43
# classification accuracy on validation set: 0.7749999761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  44
# classification accuracy on validation set: 0.78125
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 87.0%
#
# Epoch  45
# classification accuracy on validation set: 0.78125
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  46
# classification accuracy on validation set: 0.7875000238418579
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  47
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  48
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  49
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  50
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  51
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  52
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  53
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 85.0%
#
# Epoch  54
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  55
# classification accuracy on validation set: 0.800000011920929
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  56
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  57
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  58
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  59
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  60
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  61
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  62
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  63
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  64
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  65
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  66
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  67
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  68
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  69
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  70
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  71
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  72
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  73
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  74
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  75
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  76
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  77
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  78
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  79
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  80
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  81
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  82
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  83
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  84
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  85
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  86
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  87
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  88
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  89
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  90
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  91
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  92
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  93
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  94
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  95
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  96
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  97
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  98
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  99
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  100
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 9.493670463562012
# classification accuracy on test set: 86.0%
#
# Epoch  101
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-2656441ce99d> in <module>()
#      46         #print(loss)
#      47         net.zero_grad()
# ---> 48         loss.backward()
#      49         optimizer.step()
#      50         #scheduler.step(loss)
#
# ~/anaconda/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
plt.plot(val_truth)
plt.show()

# %%
plt.plot(abs(np.asarray(train_err)-np.asarray(val_err)))
plt.show()

# %%
x0 = net.conv1a(torch.unsqueeze(torch.unsqueeze(train_input[0,:,::10],0),0))
y = net.batchnorm1a(x0)
y = net.conv1b(y)
y = net.batchnorm1b(y)
y = net.conv2(y)
y = net.batchnorm2(y)
y.shape
# Out:
# torch.Size([1, 32, 1, 38])

# %%
fig, axs = plt.subplots(8, 4, sharex=True, figsize=(10,8))
# Remove horizontal space between axes
fig.subplots_adjust(hspace=0.1)

# Plot each graph, and manually set the y tick values
for i in range(4):
    for j in range(8):
        axs[j,i].plot(y.detach().numpy()[0,i+4*j,0,:])
    
plt.show()
fig.savefig('layer3_MyNet.png')
